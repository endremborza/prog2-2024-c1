# %%
import pandas as pd
import numpy as np
from scipy import spatial
import math
import polars as pl
import csv
import random
import tqdm

# %%
weapons = ["bomb", "rifle", "arrow"]

# %%
arr_random_input = np.random.default_rng().uniform(low=-100,high=100,size=[10000000,2])
arr_random_query = np.random.default_rng().uniform(low=-100,high=100,size=[1000,2])
df = pd.DataFrame(arr_random_input, columns=["x","y"])
query_df = pd.DataFrame(arr_random_query, columns=["x","y"])
df["weapon"] = "a"
df["weapon"]=df.weapon.apply(lambda x:random.choice(weapons))
df.to_parquet("notebook_results/input.parquet")
query_df.to_parquet("notebook_results/query.parquet")

# %% [markdown]
# ### This seems to work, have to create the algorithm for it

# %%
out = []
for idx, row in query_df.iterrows():

    diffs = (df[["x", "y"]] - row).pipe(lambda df: df**2).sum(axis=1)
    out.append({"dist": math.sqrt(diffs.min()), "weapon": df.loc[diffs.argmin(), "weapon"]})
pd.DataFrame(out).to_csv("notebook_results/out.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 out = []
#       2 for idx, row in query_df.iterrows():
# ----> 4     diffs = (df[["x", "y"]] - row).pipe(lambda df: df**2).sum(axis=1)
#       5     out.append({"dist": math.sqrt(diffs.min()), "weapon": df.loc[diffs.argmin(), "weapon"]})
#       6 pd.DataFrame(out).to_csv("notebook_results/out.csv", index=False)
#
# File c:\Users\tomi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11315, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11306 @doc(make_doc("sum", ndim=2))
#   11307 def sum(
#   11308     self,
#    (...)
#   11313     **kwargs,
#   11314 ):
# > 11315     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11316     return result.__finalize__(self, method="sum")
#
# File c:\Users\tomi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12064, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12056 def sum(
#   12057     self,
#   12058     axis: Axis | None = 0,
#    (...)
#   12062     **kwargs,
#   12063 ):
# > 12064     return self._min_count_stat_function(
#   12065         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12066     )
#
# File c:\Users\tomi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:12047, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12044 elif axis is lib.no_default:
#   12045     axis = 0
# > 12047 return self._reduce(
#   12048     func,
#   12049     name=name,
#   12050     axis=axis,
#   12051     skipna=skipna,
#   12052     numeric_only=numeric_only,
#   12053     min_count=min_count,
#   12054 )
#
# File c:\Users\tomi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:11211, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11209 if out_dtype is not None and out.dtype != "boolean":
#   11210     out = out.astype(out_dtype)
# > 11211 elif (df._mgr.get_dtypes() == object).any() and name not in ["any", "all"]:
#   11212     out = out.astype(object)
#   11213 elif len(self) == 0 and out.dtype == object and name in ("sum", "prod"):
#   11214     # Even if we are object dtype, follow numpy and return
#   11215     #  float64, see test_apply_funcs_over_empty
#
# File c:\Users\tomi\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:55, in _any(a, axis, dtype, out, keepdims, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#      53     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# ---> 55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
#      58         return umr_any(a, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:

# %%
# %%timeit
out = []
for idx, row in query_df.iterrows():

    diffs = (df[["x", "y"]] - row).pipe(lambda df: df**2).sum(axis=1)
    out.append({"dist": math.sqrt(diffs.min()), "weapon": df.loc[diffs.argmin(), "weapon"]})
pd.DataFrame(out).to_csv("notebook_results/out.csv", index=False)
# Out:
# 2.24 s ± 249 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# This is 20x better than the original
tree = spatial.KDTree(df[["x","y"]])
out = []
for idx, row in query_df.iterrows():
    out.append({"dist": tree.query(row)[0], "weapon": df.loc[tree.query(row)[1], "weapon"]})
#pd.DataFrame(out).to_csv("notebook_results/out_tree.csv", index=False)

# %%
# %%timeit
tree = spatial.KDTree(df[["x","y"]])
out = []
for idx, row in query_df.iterrows():
    out.append({"dist": tree.query(row)[0], "weapon": df.loc[tree.query(row)[1], "weapon"]})
#pd.DataFrame(out).to_csv("notebook_results/out_tree.csv", index=False)
# Out:
# 12.7 s ± 1.14 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# try with polars

# %%
query_df_p = pl.read_parquet("notebook_results/query.parquet")
df_p = pl.read_parquet("notebook_results/input.parquet")

# %%
#df_p = df_p.with_row_index("rownum",0)

# %%
tree = spatial.KDTree(df_p.select("x","y"))

# %%
tree.query(query_df_p[1])[1]
# Out:
# array([7096922], dtype=int64)

# %%
for row in query_df_p.iter_rows():
    asd = df_p[int(tree.query(row)[1])]["weapon"]

# %%
out = []
for row in query_df_p.iter_rows():
    out.append({"dist": tree.query(row)[0], "weapon": tree.query(row)[1]})

# %%
out = []
for row in query_df_p.iter_rows():
    out.append({"dist": tree.query(row)[0], 
                "weapon": df_p[int(tree.query(row)[1])]["weapon"].item()})

# %%
out
# Out:
# [{'dist': 0.039278713604762906, 'weapon': 'arrow'},
#  {'dist': 0.01255250093232448, 'weapon': 'arrow'},
#  {'dist': 0.0454423380376236, 'weapon': 'bomb'},
#  {'dist': 0.020370120113962855, 'weapon': 'bomb'},
#  {'dist': 0.06377640602534053, 'weapon': 'arrow'},
#  {'dist': 0.02119076022437295, 'weapon': 'arrow'},
#  {'dist': 0.039854343687682675, 'weapon': 'rifle'},
#  {'dist': 0.034926648826628916, 'weapon': 'bomb'},
#  {'dist': 0.01371150166194409, 'weapon': 'bomb'},
#  {'dist': 0.020640866877991323, 'weapon': 'rifle'},
#  {'dist': 0.022115639139974424, 'weapon': 'bomb'},
#  {'dist': 0.06262065025342188, 'weapon': 'bomb'},
#  {'dist': 0.04072283216971242, 'weapon': 'arrow'},
#  {'dist': 0.010458516002231388, 'weapon': 'rifle'},
#  {'dist': 0.008954094804945337, 'weapon': 'rifle'},
#  {'dist': 0.03429964218136761, 'weapon': 'bomb'},
#  {'dist': 0.021076181042809665, 'weapon': 'bomb'},
#  {'dist': 0.03917367220884501, 'weapon': 'bomb'},
#  {'dist': 0.04537270740664906, 'weapon': 'rifle'},
#  {'dist': 0.0351381444902152, 'weapon': 'arrow'},
#  {'dist': 0.03866294981287127, 'weapon': 'bomb'},
#  {'dist': 0.035486289050255096, 'weapon': 'bomb'},
#  {'dist': 0.0497076607418281, 'weapon': 'arrow'},
#  {'dist': 0.0045908881270787, 'weapon': 'arrow'},
#  {'dist': 0.06966150682734228, 'weapon': 'rifle'},
#  {'dist': 0.004525642746283926, 'weapon': 'bomb'},
#  {'dist': 0.012250519877394526, 'weapon': 'rifle'},
#  {'dist': 0.02452376144060215, 'weapon': 'arrow'},
#  {'dist': 0.016126459876369206, 'weapon': 'arrow'},
#  {'dist': 0.010107005847546417, 'weapon': 'arrow'},
#  {'dist': 0.060832708586193676, 'weapon': 'rifle'},
#  {'dist': 0.043219768758431906, 'weapon': 'rifle'},
#  {'dist': 0.013500057582993153, 'weapon': 'arrow'},
#  {'dist': 0.04544880397528311, 'weapon': 'arrow'},
#  {'dist': 0.06727745332080731, 'weapon': 'arrow'},
#  {'dist': 0.040124916943302356, 'weapon': 'rifle'},
#  {'dist': 0.04161900603675299, 'weapon': 'arrow'},
#  {'dist': 0.014989285610859144, 'weapon': 'arrow'},
#  {'dist': 0.016144730068892388, 'weapon': 'bomb'},
#  {'dist': 0.0119066948967786, 'weapon': 'bomb'},
#  {'dist': 0.006575603940198868, 'weapon': 'rifle'},
#  {'dist': 0.01932823875401423, 'weapon': 'arrow'},
#  {'dist': 0.022904449257983402, 'weapon': 'rifle'},
#  {'dist': 0.033623174912945135, 'weapon': 'bomb'},
#  {'dist': 0.019792779962049502, 'weapon': 'rifle'},
#  {'dist': 0.022494359498085186, 'weapon': 'rifle'},
#  {'dist': 0.03741838620920362, 'weapon': 'arrow'},
#  {'dist': 0.015182814429707602, 'weapon': 'rifle'},
#  {'dist': 0.07446731225205783, 'weapon': 'rifle'},
#  {'dist': 0.028208084653516225, 'weapon': 'arrow'},
#  {'dist': 0.024674146028536702, 'weapon': 'arrow'},
#  {'dist': 0.021096415270745475, 'weapon': 'bomb'},
#  {'dist': 0.016853377740226723, 'weapon': 'arrow'},
#  {'dist': 0.02041039925980055, 'weapon': 'arrow'},
#  {'dist': 0.04492865259449547, 'weapon': 'rifle'},
#  {'dist': 0.030742941309950474, 'weapon': 'bomb'},
#  {'dist': 0.023599503835027152, 'weapon': 'arrow'},
#  {'dist': 0.02294369824963249, 'weapon': 'arrow'},
#  {'dist': 0.025952922241805013, 'weapon': 'arrow'},
#  {'dist': 0.012373101693038622, 'weapon': 'rifle'},
#  {'dist': 0.04801234582974577, 'weapon': 'bomb'},
#  {'dist': 0.023613880630801106, 'weapon': 'rifle'},
#  {'dist': 0.057678210241802176, 'weapon': 'rifle'},
#  {'dist': 0.024022321630897413, 'weapon': 'arrow'},
#  {'dist': 0.04610568316899211, 'weapon': 'bomb'},
#  {'dist': 0.021804558308893714, 'weapon': 'rifle'},
#  {'dist': 0.06092820435023111, 'weapon': 'rifle'},
#  {'dist': 0.050803247783014545, 'weapon': 'arrow'},
#  {'dist': 0.02771135463450853, 'weapon': 'rifle'},
#  {'dist': 0.03355343782924405, 'weapon': 'bomb'},
#  {'dist': 0.025532153061592962, 'weapon': 'arrow'},
#  {'dist': 0.022802062076120833, 'weapon': 'arrow'},
#  {'dist': 0.03819096094810423, 'weapon': 'bomb'},
#  {'dist': 0.022616867536622526, 'weapon': 'arrow'},
#  {'dist': 0.028088474770782, 'weapon': 'arrow'},
#  {'dist': 0.03350530370948889, 'weapon': 'bomb'},
#  {'dist': 0.011558428142176965, 'weapon': 'rifle'},
#  {'dist': 0.02682147521976909, 'weapon': 'rifle'},
#  {'dist': 0.050825076462953304, 'weapon': 'rifle'},
#  {'dist': 0.026529188313123554, 'weapon': 'arrow'},
#  {'dist': 0.027046423930406956, 'weapon': 'rifle'},
#  {'dist': 0.023028624834240105, 'weapon': 'arrow'},
#  {'dist': 0.06348998514324697, 'weapon': 'bomb'},
#  {'dist': 0.05511428685515129, 'weapon': 'arrow'},
#  {'dist': 0.027747636081964764, 'weapon': 'bomb'},
#  {'dist': 0.07319345476186377, 'weapon': 'bomb'},
#  {'dist': 0.044310253980378383, 'weapon': 'rifle'},
#  {'dist': 0.04372421522597876, 'weapon': 'bomb'},
#  {'dist': 0.034015937332444915, 'weapon': 'rifle'},
#  {'dist': 0.05032201262201374, 'weapon': 'rifle'},
#  {'dist': 0.044746761424851095, 'weapon': 'rifle'},
#  {'dist': 0.029769394268453667, 'weapon': 'rifle'},
#  {'dist': 0.03222381733595054, 'weapon': 'bomb'},
#  {'dist': 0.03646269825517007, 'weapon': 'rifle'},
#  {'dist': 0.005793534294042099, 'weapon': 'rifle'},
#  {'dist': 0.015033794125306631, 'weapon': 'rifle'},
#  {'dist': 0.028119753595288698, 'weapon': 'bomb'},
#  {'dist': 0.05125345497205741, 'weapon': 'bomb'},
#  {'dist': 0.022789895125639135, 'weapon': 'rifle'},
#  {'dist': 0.012391754436304915, 'weapon': 'rifle'},
#  {'dist': 0.03724975328588623, 'weapon': 'rifle'},
#  {'dist': 0.032042862453389664, 'weapon': 'arrow'},
#  {'dist': 0.01846700062868923, 'weapon': 'rifle'},
#  {'dist': 0.04831300066752009, 'weapon': 'arrow'},
#  {'dist': 0.01968368540140824, 'weapon': 'bomb'},
#  {'dist': 0.008027784378201924, 'weapon': 'bomb'},
#  {'dist': 0.005640556489044998, 'weapon': 'arrow'},
#  {'dist': 0.032303086203380314, 'weapon': 'bomb'},
#  {'dist': 0.0006061453417443765, 'weapon': 'bomb'},
#  {'dist': 0.04780814718992881, 'weapon': 'rifle'},
#  {'dist': 0.027151558688943422, 'weapon': 'rifle'},
#  {'dist': 0.028334982971540516, 'weapon': 'bomb'},
#  {'dist': 0.06469275135800708, 'weapon': 'arrow'},
#  {'dist': 0.03576630814676079, 'weapon': 'arrow'},
#  {'dist': 0.0260608358353561, 'weapon': 'rifle'},
#  {'dist': 0.026987921300284722, 'weapon': 'arrow'},
#  {'dist': 0.03066871315288758, 'weapon': 'bomb'},
#  {'dist': 0.010682597499529687, 'weapon': 'bomb'},
#  {'dist': 0.02586913529488286, 'weapon': 'rifle'},
#  {'dist': 0.010959606075636412, 'weapon': 'bomb'},
#  {'dist': 0.03474473502823272, 'weapon': 'rifle'},
#  {'dist': 0.056200541162679155, 'weapon': 'arrow'},
#  {'dist': 0.029474613745491728, 'weapon': 'arrow'},
#  {'dist': 0.026599730342043944, 'weapon': 'bomb'},
#  {'dist': 0.0446619028150438, 'weapon': 'bomb'},
#  {'dist': 0.02292083343663295, 'weapon': 'arrow'},
#  {'dist': 0.013347538666870076, 'weapon': 'arrow'},
#  {'dist': 0.023382085973751587, 'weapon': 'arrow'},
#  {'dist': 0.02642139517595388, 'weapon': 'bomb'},
#  {'dist': 0.03773360586034373, 'weapon': 'bomb'},
#  {'dist': 0.04080938913993058, 'weapon': 'rifle'},
#  {'dist': 0.030794939031922854, 'weapon': 'rifle'},
#  {'dist': 0.045401786621956604, 'weapon': 'bomb'},
#  {'dist': 0.012160464182693781, 'weapon': 'bomb'},
#  {'dist': 0.01742372673226732, 'weapon': 'bomb'},
#  {'dist': 0.04530861138363874, 'weapon': 'bomb'},
#  {'dist': 0.03594860203006431, 'weapon': 'arrow'},
#  {'dist': 0.03699621951337656, 'weapon': 'arrow'},
#  {'dist': 0.022786289279641884, 'weapon': 'bomb'},
#  {'dist': 0.006697249943067992, 'weapon': 'arrow'},
#  {'dist': 0.03174627761484083, 'weapon': 'arrow'},
#  {'dist': 0.017015968119927824, 'weapon': 'bomb'},
#  {'dist': 0.019532780025761805, 'weapon': 'bomb'},
#  {'dist': 0.018760006339326354, 'weapon': 'arrow'},
#  {'dist': 0.03915626027877802, 'weapon': 'rifle'},
#  {'dist': 0.020698712782177445, 'weapon': 'arrow'},
#  {'dist': 0.03170391302225312, 'weapon': 'arrow'},
#  {'dist': 0.05634186174104134, 'weapon': 'arrow'},
#  {'dist': 0.04999258428814925, 'weapon': 'arrow'},
#  {'dist': 0.006290722330604881, 'weapon': 'arrow'},
#  {'dist': 0.040681574450812524, 'weapon': 'rifle'},
#  {'dist': 0.051429177666309514, 'weapon': 'bomb'},
#  {'dist': 0.03433112054686809, 'weapon': 'arrow'},
#  {'dist': 0.01924778583230743, 'weapon': 'arrow'},
#  {'dist': 0.024343744793284973, 'weapon': 'bomb'},
#  {'dist': 0.03436260677082654, 'weapon': 'rifle'},
#  {'dist': 0.013944804507152141, 'weapon': 'bomb'},
#  {'dist': 0.02491387436727795, 'weapon': 'rifle'},
#  {'dist': 0.06770433370930945, 'weapon': 'bomb'},
#  {'dist': 0.005524931436015862, 'weapon': 'arrow'},
#  {'dist': 0.02282762885120995, 'weapon': 'rifle'},
#  {'dist': 0.017619181924893076, 'weapon': 'arrow'},
#  {'dist': 0.024517677073617794, 'weapon': 'rifle'},
#  {'dist': 0.04019751629444837, 'weapon': 'arrow'},
#  {'dist': 0.05354107632689626, 'weapon': 'bomb'},
#  {'dist': 0.006929019400219909, 'weapon': 'arrow'},
#  {'dist': 0.037515395984403524, 'weapon': 'rifle'},
#  {'dist': 0.0355052084599704, 'weapon': 'arrow'},
#  {'dist': 0.05128960979615368, 'weapon': 'arrow'},
#  {'dist': 0.04313382084906866, 'weapon': 'bomb'},
#  {'dist': 0.010792701700570532, 'weapon': 'arrow'},
#  {'dist': 0.023427824942169773, 'weapon': 'bomb'},
#  {'dist': 0.05605930328267559, 'weapon': 'arrow'},
#  {'dist': 0.012992013425612894, 'weapon': 'bomb'},
#  {'dist': 0.011214506112141075, 'weapon': 'arrow'},
#  {'dist': 0.01562590372253163, 'weapon': 'rifle'},
#  {'dist': 0.04499578448418409, 'weapon': 'bomb'},
#  {'dist': 0.044428929166296455, 'weapon': 'arrow'},
#  {'dist': 0.006736457252880443, 'weapon': 'arrow'},
#  {'dist': 0.023966823897140953, 'weapon': 'arrow'},
#  {'dist': 0.07517061644371245, 'weapon': 'bomb'},
#  {'dist': 0.01555991334947916, 'weapon': 'arrow'},
#  {'dist': 0.04161734157871109, 'weapon': 'rifle'},
#  {'dist': 0.028638040574105267, 'weapon': 'arrow'},
#  {'dist': 0.025309293909998882, 'weapon': 'rifle'},
#  {'dist': 0.03966248572802219, 'weapon': 'bomb'},
#  {'dist': 0.04820922056839032, 'weapon': 'arrow'},
#  {'dist': 0.020586011762526443, 'weapon': 'bomb'},
#  {'dist': 0.028538047065803, 'weapon': 'arrow'},
#  {'dist': 0.01932992397923448, 'weapon': 'bomb'},
#  {'dist': 0.035427750468730694, 'weapon': 'arrow'},
#  {'dist': 0.047858332616035434, 'weapon': 'rifle'},
#  {'dist': 0.02990568127926055, 'weapon': 'rifle'},
#  {'dist': 0.03945348639208529, 'weapon': 'bomb'},
#  {'dist': 0.044378411371242675, 'weapon': 'arrow'},
#  {'dist': 0.026027308915241444, 'weapon': 'bomb'},
#  {'dist': 0.03176016394514261, 'weapon': 'arrow'},
#  {'dist': 0.014743318723268568, 'weapon': 'bomb'},
#  {'dist': 0.015706162695573164, 'weapon': 'arrow'},
#  {'dist': 0.020424675309616204, 'weapon': 'bomb'},
#  {'dist': 0.01678761440627561, 'weapon': 'rifle'},
#  {'dist': 0.009450290571600276, 'weapon': 'arrow'},
#  {'dist': 0.015117493644219573, 'weapon': 'rifle'},
#  {'dist': 0.03999317188066797, 'weapon': 'arrow'},
#  {'dist': 0.04371627168955785, 'weapon': 'rifle'},
#  {'dist': 0.01903505432954876, 'weapon': 'arrow'},
#  {'dist': 0.054586765484860925, 'weapon': 'bomb'},
#  {'dist': 0.05262947070764593, 'weapon': 'arrow'},
#  {'dist': 0.03646511221611348, 'weapon': 'arrow'},
#  {'dist': 0.060084329740716286, 'weapon': 'rifle'},
#  {'dist': 0.03701393770953261, 'weapon': 'arrow'},
#  {'dist': 0.005428742722393993, 'weapon': 'rifle'},
#  {'dist': 0.03901999904600265, 'weapon': 'rifle'},
#  {'dist': 0.03398385394825322, 'weapon': 'bomb'},
#  {'dist': 0.06313784149209459, 'weapon': 'bomb'},
#  {'dist': 0.022919703386646544, 'weapon': 'bomb'},
#  {'dist': 0.014722160899531067, 'weapon': 'arrow'},
#  {'dist': 0.042710036729888184, 'weapon': 'arrow'},
#  {'dist': 0.012580005618164707, 'weapon': 'arrow'},
#  {'dist': 0.03592070576995331, 'weapon': 'rifle'},
#  {'dist': 0.02163405480082914, 'weapon': 'bomb'},
#  {'dist': 0.018264625892917007, 'weapon': 'arrow'},
#  {'dist': 0.02607895599863759, 'weapon': 'rifle'},
#  {'dist': 0.025485225838268438, 'weapon': 'arrow'},
#  {'dist': 0.014219628086869452, 'weapon': 'arrow'},
#  {'dist': 0.02868908344322491, 'weapon': 'arrow'},
#  {'dist': 0.044014484499178635, 'weapon': 'rifle'},
#  {'dist': 0.0233974815792232, 'weapon': 'arrow'},
#  {'dist': 0.04208726803426526, 'weapon': 'bomb'},
#  {'dist': 0.0656160483041126, 'weapon': 'rifle'},
#  {'dist': 0.015649345669490944, 'weapon': 'bomb'},
#  {'dist': 0.04322048332621782, 'weapon': 'arrow'},
#  {'dist': 0.03653794455482301, 'weapon': 'bomb'},
#  {'dist': 0.04247139607140596, 'weapon': 'rifle'},
#  {'dist': 0.04072382912477563, 'weapon': 'bomb'},
#  {'dist': 0.02571295622867108, 'weapon': 'rifle'},
#  {'dist': 0.02401706956656845, 'weapon': 'arrow'},
#  {'dist': 0.033677174240234566, 'weapon': 'bomb'},
#  {'dist': 0.030853275295707826, 'weapon': 'bomb'},
#  {'dist': 0.008689394595036697, 'weapon': 'arrow'},
#  {'dist': 0.054096196827492, 'weapon': 'bomb'},
#  {'dist': 0.06850896968445659, 'weapon': 'arrow'},
#  {'dist': 0.01793392152003085, 'weapon': 'arrow'},
#  {'dist': 0.03902841357629523, 'weapon': 'bomb'},
#  {'dist': 0.009519039776071858, 'weapon': 'arrow'},
#  {'dist': 0.010687418533306164, 'weapon': 'arrow'},
#  {'dist': 0.06544894891499037, 'weapon': 'rifle'},
#  {'dist': 0.04070771068639924, 'weapon': 'arrow'},
#  {'dist': 0.025823524219608318, 'weapon': 'arrow'},
#  {'dist': 0.01857663049405915, 'weapon': 'rifle'},
#  {'dist': 0.01975730240965842, 'weapon': 'bomb'},
#  {'dist': 0.02469418179679201, 'weapon': 'arrow'},
#  {'dist': 0.029083451647262722, 'weapon': 'bomb'},
#  {'dist': 0.04933666792079489, 'weapon': 'bomb'},
#  {'dist': 0.025880415000754765, 'weapon': 'rifle'},
#  {'dist': 0.02949962984553379, 'weapon': 'bomb'},
#  {'dist': 0.025772459281437617, 'weapon': 'arrow'},
#  {'dist': 0.04368675024683109, 'weapon': 'bomb'},
#  {'dist': 0.025204979112869157, 'weapon': 'rifle'},
#  {'dist': 0.038825858009438746, 'weapon': 'rifle'},
#  {'dist': 0.007063728222320191, 'weapon': 'arrow'},
#  {'dist': 0.017398904320072434, 'weapon': 'rifle'},
#  {'dist': 0.008946469780330675, 'weapon': 'rifle'},
#  {'dist': 0.004007695075486816, 'weapon': 'arrow'},
#  {'dist': 0.05525139804941351, 'weapon': 'arrow'},
#  {'dist': 0.03958170865297513, 'weapon': 'rifle'},
#  {'dist': 0.00962362414146353, 'weapon': 'arrow'},
#  {'dist': 0.03922905617737543, 'weapon': 'arrow'},
#  {'dist': 0.030823809320765633, 'weapon': 'arrow'},
#  {'dist': 0.05550520708662527, 'weapon': 'arrow'},
#  {'dist': 0.01987991256267206, 'weapon': 'rifle'},
#  {'dist': 0.007383385429081987, 'weapon': 'bomb'},
#  {'dist': 0.032841509673989064, 'weapon': 'rifle'},
#  {'dist': 0.004697935895058127, 'weapon': 'arrow'},
#  {'dist': 0.02302242789994852, 'weapon': 'arrow'},
#  {'dist': 0.014509549225248644, 'weapon': 'arrow'},
#  {'dist': 0.05231490602792287, 'weapon': 'arrow'},
#  {'dist': 0.01823427085401553, 'weapon': 'arrow'},
#  {'dist': 0.06250351322261019, 'weapon': 'arrow'},
#  {'dist': 0.0207869304425591, 'weapon': 'rifle'},
#  {'dist': 0.029856441720590047, 'weapon': 'arrow'},
#  {'dist': 0.04469744165546329, 'weapon': 'arrow'},
#  {'dist': 0.06218680792462246, 'weapon': 'bomb'},
#  {'dist': 0.05064093799158788, 'weapon': 'rifle'},
#  {'dist': 0.053471286508953456, 'weapon': 'rifle'},
#  {'dist': 0.01623419252924815, 'weapon': 'arrow'},
#  {'dist': 0.04042499806043041, 'weapon': 'rifle'},
#  {'dist': 0.040386972867980826, 'weapon': 'arrow'},
#  {'dist': 0.0036282210289000335, 'weapon': 'arrow'},
#  {'dist': 0.01148467611051245, 'weapon': 'rifle'},
#  {'dist': 0.05858092597232155, 'weapon': 'bomb'},
#  {'dist': 0.0250863376979241, 'weapon': 'rifle'},
#  {'dist': 0.0465260971369262, 'weapon': 'bomb'},
#  {'dist': 0.04572664098376173, 'weapon': 'rifle'},
#  {'dist': 0.04167070972009249, 'weapon': 'bomb'},
#  {'dist': 0.019321789172867386, 'weapon': 'bomb'},
#  {'dist': 0.021661337164335392, 'weapon': 'rifle'},
#  {'dist': 0.020837461938516877, 'weapon': 'rifle'},
#  {'dist': 0.009293873232907472, 'weapon': 'bomb'},
#  {'dist': 0.07430425571445551, 'weapon': 'rifle'},
#  {'dist': 0.03236193632017397, 'weapon': 'arrow'},
#  {'dist': 0.035528726840556926, 'weapon': 'bomb'},
#  {'dist': 0.061311368727554556, 'weapon': 'bomb'},
#  {'dist': 0.015536528185140395, 'weapon': 'bomb'},
#  {'dist': 0.022087361019296817, 'weapon': 'arrow'},
#  {'dist': 0.04503004717348758, 'weapon': 'bomb'},
#  {'dist': 0.019701512757546513, 'weapon': 'arrow'},
#  {'dist': 0.016135447650265818, 'weapon': 'rifle'},
#  {'dist': 0.019317776258728624, 'weapon': 'rifle'},
#  {'dist': 0.01582226691571535, 'weapon': 'rifle'},
#  {'dist': 0.03014910380789951, 'weapon': 'rifle'},
#  {'dist': 0.03125720089022609, 'weapon': 'rifle'},
#  {'dist': 0.01682049714032068, 'weapon': 'rifle'},
#  {'dist': 0.034937027719669944, 'weapon': 'rifle'},
#  {'dist': 0.02307890395710119, 'weapon': 'bomb'},
#  {'dist': 0.016393976577757416, 'weapon': 'rifle'},
#  {'dist': 0.039425365203021284, 'weapon': 'bomb'},
#  {'dist': 0.04945570156850791, 'weapon': 'arrow'},
#  {'dist': 0.00477051541054915, 'weapon': 'bomb'},
#  {'dist': 0.024785708866151418, 'weapon': 'arrow'},
#  {'dist': 0.02232127584896328, 'weapon': 'rifle'},
#  {'dist': 0.04844989351603041, 'weapon': 'rifle'},
#  {'dist': 0.02073853830270689, 'weapon': 'arrow'},
#  {'dist': 0.006922507502482105, 'weapon': 'rifle'},
#  {'dist': 0.045697020199284316, 'weapon': 'arrow'},
#  {'dist': 0.03976110173802482, 'weapon': 'bomb'},
#  {'dist': 0.035628739941710966, 'weapon': 'rifle'},
#  {'dist': 0.03249823308559502, 'weapon': 'rifle'},
#  {'dist': 0.018494259706403456, 'weapon': 'bomb'},
#  {'dist': 0.036405496037488355, 'weapon': 'rifle'},
#  {'dist': 0.026577923137408557, 'weapon': 'arrow'},
#  {'dist': 0.02761648222561692, 'weapon': 'arrow'},
#  {'dist': 0.031447322627159525, 'weapon': 'rifle'},
#  {'dist': 0.014449694878510035, 'weapon': 'arrow'},
#  {'dist': 0.03176154497391184, 'weapon': 'bomb'},
#  {'dist': 0.010288529114916045, 'weapon': 'rifle'},
#  {'dist': 0.02804594903286679, 'weapon': 'rifle'},
#  {'dist': 0.0021251232715309857, 'weapon': 'arrow'},
#  {'dist': 0.03024527963173598, 'weapon': 'rifle'},
#  {'dist': 0.025869994137021093, 'weapon': 'arrow'},
#  {'dist': 0.03606215400207271, 'weapon': 'rifle'},
#  {'dist': 0.04512711787131803, 'weapon': 'arrow'},
#  {'dist': 0.028203223554573432, 'weapon': 'rifle'},
#  {'dist': 0.013101472239837271, 'weapon': 'rifle'},
#  {'dist': 0.039738256031095036, 'weapon': 'bomb'},
#  {'dist': 0.013731571176912606, 'weapon': 'arrow'},
#  {'dist': 0.02467347115742804, 'weapon': 'bomb'},
#  {'dist': 0.07163406006331707, 'weapon': 'bomb'},
#  {'dist': 0.031422397463769625, 'weapon': 'bomb'},
#  {'dist': 0.02071602881121509, 'weapon': 'rifle'},
#  {'dist': 0.014384758332444823, 'weapon': 'bomb'},
#  {'dist': 0.025208266228570208, 'weapon': 'bomb'},
#  {'dist': 0.018843939253523307, 'weapon': 'bomb'},
#  {'dist': 0.04038221279986352, 'weapon': 'rifle'},
#  {'dist': 0.0325135054623604, 'weapon': 'arrow'},
#  {'dist': 0.028111119568360633, 'weapon': 'rifle'},
#  {'dist': 0.03545424850082423, 'weapon': 'rifle'},
#  {'dist': 0.02931650654155986, 'weapon': 'arrow'},
#  {'dist': 0.05678768561342263, 'weapon': 'arrow'},
#  {'dist': 0.013646552599111232, 'weapon': 'arrow'},
#  {'dist': 0.03567569223305446, 'weapon': 'rifle'},
#  {'dist': 0.017947213747453537, 'weapon': 'arrow'},
#  {'dist': 0.02005442923700695, 'weapon': 'rifle'},
#  {'dist': 0.027324227714283365, 'weapon': 'arrow'},
#  {'dist': 0.017999895818822133, 'weapon': 'bomb'},
#  {'dist': 0.023174985398799086, 'weapon': 'rifle'},
#  {'dist': 0.005365454189666456, 'weapon': 'rifle'},
#  {'dist': 0.0629711491435112, 'weapon': 'rifle'},
#  {'dist': 0.0349384721797381, 'weapon': 'rifle'},
#  {'dist': 0.0933497136343439, 'weapon': 'arrow'},
#  {'dist': 0.040060017498528076, 'weapon': 'arrow'},
#  {'dist': 0.047257696774964074, 'weapon': 'rifle'},
#  {'dist': 0.06497951566677723, 'weapon': 'bomb'},
#  {'dist': 0.03377683910081506, 'weapon': 'bomb'},
#  {'dist': 0.04724948108637572, 'weapon': 'arrow'},
#  {'dist': 0.013274409170329593, 'weapon': 'arrow'},
#  {'dist': 0.003746340145293466, 'weapon': 'rifle'},
#  {'dist': 0.015598688629713336, 'weapon': 'bomb'},
#  {'dist': 0.04041783406283357, 'weapon': 'arrow'},
#  {'dist': 0.033437049590331516, 'weapon': 'rifle'},
#  {'dist': 0.035906026840237144, 'weapon': 'rifle'},
#  {'dist': 0.04029964896347796, 'weapon': 'bomb'},
#  {'dist': 0.03944336598218328, 'weapon': 'arrow'},
#  {'dist': 0.02329011062216525, 'weapon': 'arrow'},
#  {'dist': 0.041519871751462455, 'weapon': 'rifle'},
#  {'dist': 0.07723201485494084, 'weapon': 'bomb'},
#  {'dist': 0.019814143987842, 'weapon': 'rifle'},
#  {'dist': 0.021385704638543702, 'weapon': 'arrow'},
#  {'dist': 0.03490089879007023, 'weapon': 'rifle'},
#  {'dist': 0.02590665375108639, 'weapon': 'bomb'},
#  {'dist': 0.04778297714554584, 'weapon': 'arrow'},
#  {'dist': 0.027380327977135754, 'weapon': 'arrow'},
#  {'dist': 0.017420442299695006, 'weapon': 'rifle'},
#  {'dist': 0.018917953483534443, 'weapon': 'bomb'},
#  {'dist': 0.013812544533718258, 'weapon': 'arrow'},
#  {'dist': 0.030730632955890423, 'weapon': 'arrow'},
#  {'dist': 0.04093174163709524, 'weapon': 'arrow'},
#  {'dist': 0.024367658034113962, 'weapon': 'rifle'},
#  {'dist': 0.04615719006298096, 'weapon': 'bomb'},
#  {'dist': 0.03175548188114535, 'weapon': 'rifle'},
#  {'dist': 0.0441649156921302, 'weapon': 'rifle'},
#  {'dist': 0.039888604845626965, 'weapon': 'rifle'},
#  {'dist': 0.046968998216386844, 'weapon': 'bomb'},
#  {'dist': 0.01967531564424947, 'weapon': 'rifle'},
#  {'dist': 0.03124181227852037, 'weapon': 'arrow'},
#  {'dist': 0.048782943241246594, 'weapon': 'rifle'},
#  {'dist': 0.05155381677697803, 'weapon': 'bomb'},
#  {'dist': 0.02717594260726377, 'weapon': 'bomb'},
#  {'dist': 0.010810865198130688, 'weapon': 'rifle'},
#  {'dist': 0.02001354944763772, 'weapon': 'bomb'},
#  {'dist': 0.03784722324422326, 'weapon': 'arrow'},
#  {'dist': 0.02113533880310972, 'weapon': 'bomb'},
#  {'dist': 0.026584953449026796, 'weapon': 'bomb'},
#  {'dist': 0.011219380914898944, 'weapon': 'bomb'},
#  {'dist': 0.04409984662857453, 'weapon': 'bomb'},
#  {'dist': 0.02376777398965031, 'weapon': 'arrow'},
#  {'dist': 0.05913530334464717, 'weapon': 'arrow'},
#  {'dist': 0.04545095130002628, 'weapon': 'arrow'},
#  {'dist': 0.018059909014051058, 'weapon': 'rifle'},
#  {'dist': 0.03897217960098728, 'weapon': 'arrow'},
#  {'dist': 0.015721303300635203, 'weapon': 'rifle'},
#  {'dist': 0.025682804552149337, 'weapon': 'bomb'},
#  {'dist': 0.026271095077682546, 'weapon': 'arrow'},
#  {'dist': 0.040673882252775115, 'weapon': 'rifle'},
#  {'dist': 0.004198273375982897, 'weapon': 'bomb'},
#  {'dist': 0.02310190793865021, 'weapon': 'arrow'},
#  {'dist': 0.026172425071136585, 'weapon': 'bomb'},
#  {'dist': 0.02606354737385741, 'weapon': 'rifle'},
#  {'dist': 0.037001900546227026, 'weapon': 'arrow'},
#  {'dist': 0.023125966241419348, 'weapon': 'arrow'},
#  {'dist': 0.024362588857254074, 'weapon': 'rifle'},
#  {'dist': 0.02128599428021155, 'weapon': 'rifle'},
#  {'dist': 0.020036617443729386, 'weapon': 'arrow'},
#  {'dist': 0.045832631881043584, 'weapon': 'bomb'},
#  {'dist': 0.02117442386021242, 'weapon': 'rifle'},
#  {'dist': 0.036061877620754204, 'weapon': 'bomb'},
#  {'dist': 0.021500696524044623, 'weapon': 'arrow'},
#  {'dist': 0.058016407050993174, 'weapon': 'rifle'},
#  {'dist': 0.02645384879586142, 'weapon': 'arrow'},
#  {'dist': 0.01728584733925378, 'weapon': 'bomb'},
#  {'dist': 0.04060172781723885, 'weapon': 'rifle'},
#  {'dist': 0.01823815749149735, 'weapon': 'rifle'},
#  {'dist': 0.0402523888339041, 'weapon': 'bomb'},
#  {'dist': 0.02500543106217653, 'weapon': 'arrow'},
#  {'dist': 0.030121017420099615, 'weapon': 'arrow'},
#  {'dist': 0.05673664766675149, 'weapon': 'rifle'},
#  {'dist': 0.024712472076725514, 'weapon': 'arrow'},
#  {'dist': 0.044475192633762414, 'weapon': 'rifle'},
#  {'dist': 0.02605130028259504, 'weapon': 'bomb'},
#  {'dist': 0.03480552873877192, 'weapon': 'arrow'},
#  {'dist': 0.04155134062223491, 'weapon': 'arrow'},
#  {'dist': 0.028778711894033183, 'weapon': 'arrow'},
#  {'dist': 0.03387267668610884, 'weapon': 'rifle'},
#  {'dist': 0.034551870550746905, 'weapon': 'rifle'},
#  {'dist': 0.011323336480319681, 'weapon': 'arrow'},
#  {'dist': 0.037412533335434414, 'weapon': 'bomb'},
#  {'dist': 0.044909738913163084, 'weapon': 'rifle'},
#  {'dist': 0.014267112148015099, 'weapon': 'bomb'},
#  {'dist': 0.028020538700382992, 'weapon': 'bomb'},
#  {'dist': 0.0025760721265768016, 'weapon': 'rifle'},
#  {'dist': 0.04078687169622097, 'weapon': 'bomb'},
#  {'dist': 0.032164116554043935, 'weapon': 'bomb'},
#  {'dist': 0.025058032568777748, 'weapon': 'arrow'},
#  {'dist': 0.05923407713580736, 'weapon': 'rifle'},
#  {'dist': 0.025897375745375255, 'weapon': 'arrow'},
#  {'dist': 0.053851521792755576, 'weapon': 'rifle'},
#  {'dist': 0.032029816613185345, 'weapon': 'bomb'},
#  {'dist': 0.05385604725728826, 'weapon': 'arrow'},
#  {'dist': 0.008955350836023696, 'weapon': 'arrow'},
#  {'dist': 0.022951962222865524, 'weapon': 'arrow'},
#  {'dist': 0.054801253247035116, 'weapon': 'rifle'},
#  {'dist': 0.024326304956150794, 'weapon': 'rifle'},
#  {'dist': 0.03830708193374187, 'weapon': 'bomb'},
#  {'dist': 0.04875201994808491, 'weapon': 'rifle'},
#  {'dist': 0.08183732348020376, 'weapon': 'arrow'},
#  {'dist': 0.059292763967893077, 'weapon': 'rifle'},
#  {'dist': 0.022670252012178913, 'weapon': 'rifle'},
#  {'dist': 0.025086341331852058, 'weapon': 'arrow'},
#  {'dist': 0.04132674443488171, 'weapon': 'rifle'},
#  {'dist': 0.01613834301703028, 'weapon': 'rifle'},
#  {'dist': 0.038680266843030935, 'weapon': 'rifle'},
#  {'dist': 0.02662788729860467, 'weapon': 'bomb'},
#  {'dist': 0.06030540454141146, 'weapon': 'bomb'},
#  {'dist': 0.009494457581537673, 'weapon': 'rifle'},
#  {'dist': 0.0031928156150443526, 'weapon': 'rifle'},
#  {'dist': 0.020098747502759157, 'weapon': 'arrow'},
#  {'dist': 0.005028782704584784, 'weapon': 'arrow'},
#  {'dist': 0.04109531356143594, 'weapon': 'bomb'},
#  {'dist': 0.034416835440256976, 'weapon': 'rifle'},
#  {'dist': 0.017612290401424025, 'weapon': 'rifle'},
#  {'dist': 0.017493163622643016, 'weapon': 'bomb'},
#  {'dist': 0.0285506324976641, 'weapon': 'bomb'},
#  {'dist': 0.027331208547504825, 'weapon': 'arrow'},
#  {'dist': 0.030884083987679733, 'weapon': 'rifle'},
#  {'dist': 0.06658048814102928, 'weapon': 'bomb'},
#  {'dist': 0.0298723122498643, 'weapon': 'arrow'},
#  {'dist': 0.02463248141467367, 'weapon': 'rifle'},
#  {'dist': 0.013616224670512201, 'weapon': 'arrow'},
#  {'dist': 0.02403599556410285, 'weapon': 'rifle'},
#  {'dist': 0.01760102462693521, 'weapon': 'bomb'},
#  {'dist': 0.027769481729684072, 'weapon': 'arrow'},
#  {'dist': 0.04249226168413412, 'weapon': 'arrow'},
#  {'dist': 0.02440699220085982, 'weapon': 'bomb'},
#  {'dist': 0.026876140709634774, 'weapon': 'arrow'},
#  {'dist': 0.029000722139330453, 'weapon': 'bomb'},
#  {'dist': 0.012361140249066876, 'weapon': 'arrow'},
#  {'dist': 0.05061552783902091, 'weapon': 'bomb'},
#  {'dist': 0.03634344573729111, 'weapon': 'rifle'},
#  {'dist': 0.016348513178182797, 'weapon': 'arrow'},
#  {'dist': 0.03319688605305001, 'weapon': 'arrow'},
#  {'dist': 0.04860000941475218, 'weapon': 'arrow'},
#  {'dist': 0.024509765634598713, 'weapon': 'bomb'},
#  {'dist': 0.01757801048308868, 'weapon': 'bomb'},
#  {'dist': 0.025940839348091067, 'weapon': 'arrow'},
#  {'dist': 0.03940943496803862, 'weapon': 'arrow'},
#  {'dist': 0.008232737001616116, 'weapon': 'bomb'},
#  {'dist': 0.03285117092589427, 'weapon': 'rifle'},
#  {'dist': 0.068331548020137, 'weapon': 'rifle'},
#  {'dist': 0.004924321926385323, 'weapon': 'rifle'},
#  {'dist': 0.04130221754852447, 'weapon': 'bomb'},
#  {'dist': 0.0444079395355764, 'weapon': 'rifle'},
#  {'dist': 0.04852797679737671, 'weapon': 'arrow'},
#  {'dist': 0.03100656863382984, 'weapon': 'bomb'},
#  {'dist': 0.0360757995784798, 'weapon': 'rifle'},
#  {'dist': 0.052694782963802145, 'weapon': 'rifle'},
#  {'dist': 0.069968407000597, 'weapon': 'arrow'},
#  {'dist': 0.045646587206386355, 'weapon': 'arrow'},
#  {'dist': 0.03147013446282787, 'weapon': 'arrow'},
#  {'dist': 0.031099942065363265, 'weapon': 'bomb'},
#  {'dist': 0.04383192323293301, 'weapon': 'arrow'},
#  {'dist': 0.05936291809439136, 'weapon': 'bomb'},
#  {'dist': 0.04270175027377847, 'weapon': 'bomb'},
#  {'dist': 0.023321532042214033, 'weapon': 'rifle'},
#  {'dist': 0.05409276289506432, 'weapon': 'bomb'},
#  {'dist': 0.022793613807157075, 'weapon': 'arrow'},
#  {'dist': 0.025577214317166468, 'weapon': 'rifle'},
#  {'dist': 0.014947574020954887, 'weapon': 'arrow'},
#  {'dist': 0.023082313127140153, 'weapon': 'bomb'},
#  {'dist': 0.053522772750526804, 'weapon': 'bomb'},
#  {'dist': 0.026887816489900268, 'weapon': 'rifle'},
#  {'dist': 0.01750531108967619, 'weapon': 'bomb'},
#  {'dist': 0.029927043676929034, 'weapon': 'rifle'},
#  {'dist': 0.03477418628316628, 'weapon': 'bomb'},
#  {'dist': 0.005168213511496898, 'weapon': 'arrow'},
#  {'dist': 0.020782355002824687, 'weapon': 'rifle'},
#  {'dist': 0.03710793824068757, 'weapon': 'bomb'},
#  {'dist': 0.0265944694313179, 'weapon': 'arrow'},
#  {'dist': 0.04192467293546275, 'weapon': 'bomb'},
#  {'dist': 0.01646272822840851, 'weapon': 'rifle'},
#  {'dist': 0.013457321866022087, 'weapon': 'bomb'},
#  {'dist': 0.03683896335747923, 'weapon': 'arrow'},
#  {'dist': 0.04304295033753932, 'weapon': 'rifle'},
#  {'dist': 0.01484367225350181, 'weapon': 'arrow'},
#  {'dist': 0.040185863978034496, 'weapon': 'bomb'},
#  {'dist': 0.044879881993981796, 'weapon': 'arrow'},
#  {'dist': 0.014414451090629365, 'weapon': 'arrow'},
#  {'dist': 0.051405161530343156, 'weapon': 'bomb'},
#  {'dist': 0.02108665197080635, 'weapon': 'rifle'},
#  {'dist': 0.03213858049209858, 'weapon': 'rifle'},
#  {'dist': 0.014629812580514575, 'weapon': 'bomb'},
#  {'dist': 0.03210610534625279, 'weapon': 'bomb'},
#  {'dist': 0.016773036914915388, 'weapon': 'rifle'},
#  {'dist': 0.02307191254778631, 'weapon': 'rifle'},
#  {'dist': 0.06313964874361173, 'weapon': 'arrow'},
#  {'dist': 0.07433326406088804, 'weapon': 'arrow'},
#  {'dist': 0.037781634156713, 'weapon': 'rifle'},
#  {'dist': 0.03827880909949143, 'weapon': 'rifle'},
#  {'dist': 0.025099999624155673, 'weapon': 'bomb'},
#  {'dist': 0.06270692562754412, 'weapon': 'rifle'},
#  {'dist': 0.02528159415662733, 'weapon': 'rifle'},
#  {'dist': 0.026063663299335856, 'weapon': 'arrow'},
#  {'dist': 0.029060859315569933, 'weapon': 'arrow'},
#  {'dist': 0.041758701273120785, 'weapon': 'rifle'},
#  {'dist': 0.05556825947263909, 'weapon': 'bomb'},
#  {'dist': 0.039332220078655084, 'weapon': 'arrow'},
#  {'dist': 0.021029183704847507, 'weapon': 'arrow'},
#  {'dist': 0.04457395064031186, 'weapon': 'arrow'},
#  {'dist': 0.03301112675019902, 'weapon': 'rifle'},
#  {'dist': 0.07993308615399465, 'weapon': 'bomb'},
#  {'dist': 0.04611332272008058, 'weapon': 'bomb'},
#  {'dist': 0.031265365816041446, 'weapon': 'arrow'},
#  {'dist': 0.050812022486879514, 'weapon': 'rifle'},
#  {'dist': 0.0024937179066590377, 'weapon': 'bomb'},
#  {'dist': 0.011725999453469929, 'weapon': 'rifle'},
#  {'dist': 0.026242675971327904, 'weapon': 'rifle'},
#  {'dist': 0.006536482930487447, 'weapon': 'arrow'},
#  {'dist': 0.021777472048134162, 'weapon': 'arrow'},
#  {'dist': 0.007812728865061598, 'weapon': 'bomb'},
#  {'dist': 0.014303667286423509, 'weapon': 'rifle'},
#  {'dist': 0.007727237337572277, 'weapon': 'rifle'},
#  {'dist': 0.0367261599597844, 'weapon': 'bomb'},
#  {'dist': 0.026672164723962128, 'weapon': 'rifle'},
#  {'dist': 0.0260819795169454, 'weapon': 'bomb'},
#  {'dist': 0.033420350179615345, 'weapon': 'rifle'},
#  {'dist': 0.017070914402350246, 'weapon': 'arrow'},
#  {'dist': 0.03371290001857194, 'weapon': 'arrow'},
#  {'dist': 0.0442034246817599, 'weapon': 'bomb'},
#  {'dist': 0.03980328616735298, 'weapon': 'rifle'},
#  {'dist': 0.028641835392863593, 'weapon': 'bomb'},
#  {'dist': 0.015853850973645556, 'weapon': 'arrow'},
#  {'dist': 0.02454154929192221, 'weapon': 'bomb'},
#  {'dist': 0.048995498316231206, 'weapon': 'arrow'},
#  {'dist': 0.03289111259467131, 'weapon': 'arrow'},
#  {'dist': 0.009188056749946086, 'weapon': 'rifle'},
#  {'dist': 0.02262380340808127, 'weapon': 'arrow'},
#  {'dist': 0.03654144357476923, 'weapon': 'bomb'},
#  {'dist': 0.021641912515685483, 'weapon': 'bomb'},
#  {'dist': 0.038014241102648734, 'weapon': 'bomb'},
#  {'dist': 0.03385964275680891, 'weapon': 'rifle'},
#  {'dist': 0.015473163658118995, 'weapon': 'arrow'},
#  {'dist': 0.04937982202903296, 'weapon': 'bomb'},
#  {'dist': 0.06818416283192938, 'weapon': 'arrow'},
#  {'dist': 0.015509040390624285, 'weapon': 'bomb'},
#  {'dist': 0.01642342247215886, 'weapon': 'rifle'},
#  {'dist': 0.010717570020500816, 'weapon': 'rifle'},
#  {'dist': 0.02940212007500982, 'weapon': 'bomb'},
#  {'dist': 0.040731764260534785, 'weapon': 'rifle'},
#  {'dist': 0.04330523593955649, 'weapon': 'bomb'},
#  {'dist': 0.04310611147832535, 'weapon': 'rifle'},
#  {'dist': 0.009157748460814739, 'weapon': 'rifle'},
#  {'dist': 0.012675093445763959, 'weapon': 'rifle'},
#  {'dist': 0.03496047773219894, 'weapon': 'rifle'},
#  {'dist': 0.02182659764398937, 'weapon': 'rifle'},
#  {'dist': 0.04619563800678756, 'weapon': 'bomb'},
#  {'dist': 0.035514695807863456, 'weapon': 'rifle'},
#  {'dist': 0.010888978337991228, 'weapon': 'rifle'},
#  {'dist': 0.04558208557811436, 'weapon': 'bomb'},
#  {'dist': 0.024658831888699544, 'weapon': 'bomb'},
#  {'dist': 0.033303573279600006, 'weapon': 'bomb'},
#  {'dist': 0.031104749924423514, 'weapon': 'arrow'},
#  {'dist': 0.017965585189139235, 'weapon': 'bomb'},
#  {'dist': 0.024362366269907294, 'weapon': 'bomb'},
#  {'dist': 0.04203885572347555, 'weapon': 'rifle'},
#  {'dist': 0.05154220743173888, 'weapon': 'bomb'},
#  {'dist': 0.0406723207850114, 'weapon': 'bomb'},
#  {'dist': 0.015462675848448793, 'weapon': 'arrow'},
#  {'dist': 0.027310131791719875, 'weapon': 'bomb'},
#  {'dist': 0.010214077466820097, 'weapon': 'bomb'},
#  {'dist': 0.022705126693488824, 'weapon': 'rifle'},
#  {'dist': 0.02946367596758667, 'weapon': 'bomb'},
#  {'dist': 0.06399357012775465, 'weapon': 'rifle'},
#  {'dist': 0.023830742047873412, 'weapon': 'arrow'},
#  {'dist': 0.05466790958435969, 'weapon': 'arrow'},
#  {'dist': 0.0249967511879927, 'weapon': 'bomb'},
#  {'dist': 0.017269934287190706, 'weapon': 'bomb'},
#  {'dist': 0.0626272620695471, 'weapon': 'rifle'},
#  {'dist': 0.018409671595871244, 'weapon': 'bomb'},
#  {'dist': 0.01797004462798967, 'weapon': 'rifle'},
#  {'dist': 0.020271465215141914, 'weapon': 'rifle'},
#  {'dist': 0.03294687553327667, 'weapon': 'bomb'},
#  {'dist': 0.03359911198310469, 'weapon': 'rifle'},
#  {'dist': 0.01382142857318086, 'weapon': 'rifle'},
#  {'dist': 0.012116122059581699, 'weapon': 'rifle'},
#  {'dist': 0.006225777753365668, 'weapon': 'rifle'},
#  {'dist': 0.055803349933487116, 'weapon': 'arrow'},
#  {'dist': 0.04659927817762631, 'weapon': 'arrow'},
#  {'dist': 0.02829186663632078, 'weapon': 'rifle'},
#  {'dist': 0.04893139571581219, 'weapon': 'rifle'},
#  {'dist': 0.05171380290125711, 'weapon': 'bomb'},
#  {'dist': 0.011638029306571073, 'weapon': 'rifle'},
#  {'dist': 0.029857807911355862, 'weapon': 'rifle'},
#  {'dist': 0.029340920976232452, 'weapon': 'arrow'},
#  {'dist': 0.02787967156326044, 'weapon': 'bomb'},
#  {'dist': 0.02911077332676128, 'weapon': 'arrow'},
#  {'dist': 0.03448582967872571, 'weapon': 'rifle'},
#  {'dist': 0.025645739086050907, 'weapon': 'arrow'},
#  {'dist': 0.060659354465725464, 'weapon': 'bomb'},
#  {'dist': 0.02232226323028886, 'weapon': 'bomb'},
#  {'dist': 0.024612241676509463, 'weapon': 'rifle'},
#  {'dist': 0.0779608308149525, 'weapon': 'arrow'},
#  {'dist': 0.03916256921251945, 'weapon': 'bomb'},
#  {'dist': 0.005926731855645893, 'weapon': 'rifle'},
#  {'dist': 0.024634457701695922, 'weapon': 'bomb'},
#  {'dist': 0.022179358487785492, 'weapon': 'rifle'},
#  {'dist': 0.03856267188024259, 'weapon': 'arrow'},
#  {'dist': 0.018806548951316025, 'weapon': 'rifle'},
#  {'dist': 0.03804553861947176, 'weapon': 'rifle'},
#  {'dist': 0.056813792138058594, 'weapon': 'bomb'},
#  {'dist': 0.023626464076527746, 'weapon': 'rifle'},
#  {'dist': 0.0467663239421123, 'weapon': 'rifle'},
#  {'dist': 0.006094741236689126, 'weapon': 'arrow'},
#  {'dist': 0.05714909111628035, 'weapon': 'arrow'},
#  {'dist': 0.02819553381996714, 'weapon': 'rifle'},
#  {'dist': 0.02190500219377196, 'weapon': 'arrow'},
#  {'dist': 0.02313232691494338, 'weapon': 'bomb'},
#  {'dist': 0.025520072446451, 'weapon': 'rifle'},
#  {'dist': 0.05457425924960783, 'weapon': 'arrow'},
#  {'dist': 0.026312434506690758, 'weapon': 'rifle'},
#  {'dist': 0.012815394966670765, 'weapon': 'rifle'},
#  {'dist': 0.026697708578919607, 'weapon': 'rifle'},
#  {'dist': 0.06909203691584141, 'weapon': 'arrow'},
#  {'dist': 0.039092386535556585, 'weapon': 'rifle'},
#  {'dist': 0.03861791360184792, 'weapon': 'bomb'},
#  {'dist': 0.023775033447410675, 'weapon': 'bomb'},
#  {'dist': 0.01755359177243444, 'weapon': 'arrow'},
#  {'dist': 0.02435058484857564, 'weapon': 'arrow'},
#  {'dist': 0.026466791789146963, 'weapon': 'bomb'},
#  {'dist': 0.04574604775864194, 'weapon': 'arrow'},
#  {'dist': 0.05224894393618945, 'weapon': 'rifle'},
#  {'dist': 0.0332889138661611, 'weapon': 'arrow'},
#  {'dist': 0.03972494594751312, 'weapon': 'bomb'},
#  {'dist': 0.04628512735035701, 'weapon': 'rifle'},
#  {'dist': 0.05039885606921427, 'weapon': 'bomb'},
#  {'dist': 0.018122082538726426, 'weapon': 'arrow'},
#  {'dist': 0.012660348053871328, 'weapon': 'rifle'},
#  {'dist': 0.024291148297599558, 'weapon': 'arrow'},
#  {'dist': 0.05735998624044471, 'weapon': 'arrow'},
#  {'dist': 0.037287193573489544, 'weapon': 'bomb'},
#  {'dist': 0.018545165953749537, 'weapon': 'rifle'},
#  {'dist': 0.044344072370450315, 'weapon': 'bomb'},
#  {'dist': 0.04829221027270504, 'weapon': 'arrow'},
#  {'dist': 0.009224741387052591, 'weapon': 'rifle'},
#  {'dist': 0.060578175331306265, 'weapon': 'bomb'},
#  {'dist': 0.08076289175192487, 'weapon': 'arrow'},
#  {'dist': 0.01890393711393067, 'weapon': 'bomb'},
#  {'dist': 0.007205161117416082, 'weapon': 'bomb'},
#  {'dist': 0.0057812885624954295, 'weapon': 'bomb'},
#  {'dist': 0.01241632637077652, 'weapon': 'bomb'},
#  {'dist': 0.014887444576885862, 'weapon': 'arrow'},
#  {'dist': 0.012925355159647826, 'weapon': 'arrow'},
#  {'dist': 0.024580564389274223, 'weapon': 'arrow'},
#  {'dist': 0.0520526740255658, 'weapon': 'bomb'},
#  {'dist': 0.049488072645715524, 'weapon': 'rifle'},
#  {'dist': 0.01659691987850894, 'weapon': 'rifle'},
#  {'dist': 0.035077046299710486, 'weapon': 'rifle'},
#  {'dist': 0.0502250688282928, 'weapon': 'arrow'},
#  {'dist': 0.034269296674525, 'weapon': 'arrow'},
#  {'dist': 0.0072704504059388254, 'weapon': 'bomb'},
#  {'dist': 0.045729794327286626, 'weapon': 'rifle'},
#  {'dist': 0.03211176424417613, 'weapon': 'rifle'},
#  {'dist': 0.012172668926475757, 'weapon': 'arrow'},
#  {'dist': 0.028118257855559426, 'weapon': 'bomb'},
#  {'dist': 0.01240526643129683, 'weapon': 'bomb'},
#  {'dist': 0.0014768491974295754, 'weapon': 'rifle'},
#  {'dist': 0.030708628072675607, 'weapon': 'arrow'},
#  {'dist': 0.037627112194883586, 'weapon': 'rifle'},
#  {'dist': 0.003908458593591976, 'weapon': 'arrow'},
#  {'dist': 0.0340911690771907, 'weapon': 'arrow'},
#  {'dist': 0.07058908598763465, 'weapon': 'bomb'},
#  {'dist': 0.01808681072907594, 'weapon': 'bomb'},
#  {'dist': 0.047896091881126146, 'weapon': 'rifle'},
#  {'dist': 0.016277239664648873, 'weapon': 'bomb'},
#  {'dist': 0.02443078105702356, 'weapon': 'arrow'},
#  {'dist': 0.023190173880267145, 'weapon': 'rifle'},
#  {'dist': 0.013106557167362538, 'weapon': 'arrow'},
#  {'dist': 0.03651628064497293, 'weapon': 'arrow'},
#  {'dist': 0.033358519595394306, 'weapon': 'bomb'},
#  {'dist': 0.017531036295937094, 'weapon': 'rifle'},
#  {'dist': 0.039807065816575934, 'weapon': 'rifle'},
#  {'dist': 0.014581903178555133, 'weapon': 'bomb'},
#  {'dist': 0.007487950618921557, 'weapon': 'rifle'},
#  {'dist': 0.010798716026509166, 'weapon': 'arrow'},
#  {'dist': 0.032478253193885066, 'weapon': 'arrow'},
#  {'dist': 0.034879496190658596, 'weapon': 'rifle'},
#  {'dist': 0.05934956479733889, 'weapon': 'bomb'},
#  {'dist': 0.004970218826925692, 'weapon': 'arrow'},
#  {'dist': 0.028934446701486552, 'weapon': 'arrow'},
#  {'dist': 0.06550129911648925, 'weapon': 'bomb'},
#  {'dist': 0.011670139642928939, 'weapon': 'arrow'},
#  {'dist': 0.01798190378197744, 'weapon': 'bomb'},
#  {'dist': 0.03695686781322126, 'weapon': 'rifle'},
#  {'dist': 0.02357899797814421, 'weapon': 'arrow'},
#  {'dist': 0.06887731156797175, 'weapon': 'rifle'},
#  {'dist': 0.03835775869327045, 'weapon': 'arrow'},
#  {'dist': 0.05670377432564723, 'weapon': 'rifle'},
#  {'dist': 0.04412530564483702, 'weapon': 'rifle'},
#  {'dist': 0.02708304971458355, 'weapon': 'rifle'},
#  {'dist': 0.03320342867586937, 'weapon': 'rifle'},
#  {'dist': 0.04333753818057547, 'weapon': 'bomb'},
#  {'dist': 0.0626202858171435, 'weapon': 'rifle'},
#  {'dist': 0.029481261165613455, 'weapon': 'arrow'},
#  {'dist': 0.03596599582487963, 'weapon': 'rifle'},
#  {'dist': 0.03630943899529865, 'weapon': 'arrow'},
#  {'dist': 0.015247916353953596, 'weapon': 'rifle'},
#  {'dist': 0.009808778437772274, 'weapon': 'bomb'},
#  {'dist': 0.041833565715741636, 'weapon': 'rifle'},
#  {'dist': 0.018630832352308804, 'weapon': 'arrow'},
#  {'dist': 0.025869828146274698, 'weapon': 'rifle'},
#  {'dist': 0.01416518557957831, 'weapon': 'arrow'},
#  {'dist': 0.03451885724980427, 'weapon': 'rifle'},
#  {'dist': 0.01998729236273673, 'weapon': 'rifle'},
#  {'dist': 0.005842349669438195, 'weapon': 'bomb'},
#  {'dist': 0.06101341929445004, 'weapon': 'rifle'},
#  {'dist': 0.08019471737824502, 'weapon': 'bomb'},
#  {'dist': 0.020229755525288995, 'weapon': 'bomb'},
#  {'dist': 0.009833633702115626, 'weapon': 'rifle'},
#  {'dist': 0.04971962027443331, 'weapon': 'rifle'},
#  {'dist': 0.008183708607467689, 'weapon': 'bomb'},
#  {'dist': 0.011338827925758002, 'weapon': 'bomb'},
#  {'dist': 0.06181727233066527, 'weapon': 'arrow'},
#  {'dist': 0.03116063377189256, 'weapon': 'bomb'},
#  {'dist': 0.011340344006643566, 'weapon': 'arrow'},
#  {'dist': 0.0147205819701217, 'weapon': 'bomb'},
#  {'dist': 0.038987872570779444, 'weapon': 'rifle'},
#  {'dist': 0.02756762055341008, 'weapon': 'bomb'},
#  {'dist': 0.020203324882817675, 'weapon': 'rifle'},
#  {'dist': 0.008799407277652148, 'weapon': 'rifle'},
#  {'dist': 0.0455806088708243, 'weapon': 'bomb'},
#  {'dist': 0.03706526339379782, 'weapon': 'rifle'},
#  {'dist': 0.052932862042141156, 'weapon': 'rifle'},
#  {'dist': 0.015270431566741925, 'weapon': 'bomb'},
#  {'dist': 0.03887551140953067, 'weapon': 'bomb'},
#  {'dist': 0.026799790364572845, 'weapon': 'rifle'},
#  {'dist': 0.02013083315601634, 'weapon': 'rifle'},
#  {'dist': 0.01646348044124303, 'weapon': 'bomb'},
#  {'dist': 0.021011180797537297, 'weapon': 'arrow'},
#  {'dist': 0.03050063190349131, 'weapon': 'bomb'},
#  {'dist': 0.03850184028251974, 'weapon': 'rifle'},
#  {'dist': 0.03151120034782734, 'weapon': 'rifle'},
#  {'dist': 0.022122722955165926, 'weapon': 'arrow'},
#  {'dist': 0.05642867155517476, 'weapon': 'bomb'},
#  {'dist': 0.0276913869871571, 'weapon': 'bomb'},
#  {'dist': 0.03616199975672532, 'weapon': 'arrow'},
#  {'dist': 0.028791528861172266, 'weapon': 'bomb'},
#  {'dist': 0.0318634843881575, 'weapon': 'bomb'},
#  {'dist': 0.021573369913628963, 'weapon': 'rifle'},
#  {'dist': 0.027059987300715287, 'weapon': 'rifle'},
#  {'dist': 0.029717257234174437, 'weapon': 'bomb'},
#  {'dist': 0.04424251377157256, 'weapon': 'arrow'},
#  {'dist': 0.02002337389898417, 'weapon': 'bomb'},
#  {'dist': 0.01064781152147602, 'weapon': 'rifle'},
#  {'dist': 0.03654683284205939, 'weapon': 'arrow'},
#  {'dist': 0.022547812155462452, 'weapon': 'arrow'},
#  {'dist': 0.013082957425789741, 'weapon': 'arrow'},
#  {'dist': 0.03261019995694304, 'weapon': 'arrow'},
#  {'dist': 0.03616187253919127, 'weapon': 'arrow'},
#  {'dist': 0.017155953387070728, 'weapon': 'arrow'},
#  {'dist': 0.023698825657386517, 'weapon': 'bomb'},
#  {'dist': 0.07096747881295334, 'weapon': 'bomb'},
#  {'dist': 0.014682021573264354, 'weapon': 'arrow'},
#  {'dist': 0.023527468981996355, 'weapon': 'arrow'},
#  {'dist': 0.02173904337459092, 'weapon': 'arrow'},
#  {'dist': 0.018576098318820376, 'weapon': 'arrow'},
#  {'dist': 0.004211796694781185, 'weapon': 'arrow'},
#  {'dist': 0.057011230757934565, 'weapon': 'bomb'},
#  {'dist': 0.035414101437935705, 'weapon': 'arrow'},
#  {'dist': 0.011804474032941586, 'weapon': 'rifle'},
#  {'dist': 0.015700193330360206, 'weapon': 'rifle'},
#  {'dist': 0.021873467277280102, 'weapon': 'bomb'},
#  {'dist': 0.015503402153128776, 'weapon': 'bomb'},
#  {'dist': 0.06611472265873508, 'weapon': 'rifle'},
#  {'dist': 0.020741633554175264, 'weapon': 'arrow'},
#  {'dist': 0.03334582030540998, 'weapon': 'bomb'},
#  {'dist': 0.015942951560068197, 'weapon': 'arrow'},
#  {'dist': 0.007312336608154694, 'weapon': 'bomb'},
#  {'dist': 0.024688114245926294, 'weapon': 'arrow'},
#  {'dist': 0.014719042269799185, 'weapon': 'bomb'},
#  {'dist': 0.04798328248521632, 'weapon': 'rifle'},
#  {'dist': 0.03243274921196726, 'weapon': 'arrow'},
#  {'dist': 0.058880580481623895, 'weapon': 'rifle'},
#  {'dist': 0.03362393488422169, 'weapon': 'bomb'},
#  {'dist': 0.026980676894875176, 'weapon': 'arrow'},
#  {'dist': 0.049223965095478064, 'weapon': 'arrow'},
#  {'dist': 0.057866523213493795, 'weapon': 'arrow'},
#  {'dist': 0.08819784339214641, 'weapon': 'rifle'},
#  {'dist': 0.0352505694054367, 'weapon': 'rifle'},
#  {'dist': 0.024028066480999546, 'weapon': 'bomb'},
#  {'dist': 0.006997337566794364, 'weapon': 'arrow'},
#  {'dist': 0.007735814717407607, 'weapon': 'bomb'},
#  {'dist': 0.014274975025888917, 'weapon': 'rifle'},
#  {'dist': 0.006487226214535903, 'weapon': 'arrow'},
#  {'dist': 0.0040068671280822175, 'weapon': 'bomb'},
#  {'dist': 0.02121869885097702, 'weapon': 'arrow'},
#  {'dist': 0.03186341897157583, 'weapon': 'bomb'},
#  {'dist': 0.022779299280452688, 'weapon': 'arrow'},
#  {'dist': 0.058085504851698375, 'weapon': 'bomb'},
#  {'dist': 0.07137344826942901, 'weapon': 'arrow'},
#  {'dist': 0.03797992255550449, 'weapon': 'bomb'},
#  {'dist': 0.03467495564231582, 'weapon': 'rifle'},
#  {'dist': 0.039119619078111977, 'weapon': 'arrow'},
#  {'dist': 0.027085307461623156, 'weapon': 'rifle'},
#  {'dist': 0.011729205139144208, 'weapon': 'rifle'},
#  {'dist': 0.008769164898197184, 'weapon': 'rifle'},
#  {'dist': 0.031836177508592876, 'weapon': 'arrow'},
#  {'dist': 0.03389022741843047, 'weapon': 'bomb'},
#  {'dist': 0.03153991010414496, 'weapon': 'bomb'},
#  {'dist': 0.07039814367052488, 'weapon': 'arrow'},
#  {'dist': 0.02207007281672883, 'weapon': 'rifle'},
#  {'dist': 0.03545635131263209, 'weapon': 'rifle'},
#  {'dist': 0.019278491614679937, 'weapon': 'arrow'},
#  {'dist': 0.04108516053834484, 'weapon': 'rifle'},
#  {'dist': 0.024590760120364707, 'weapon': 'rifle'},
#  {'dist': 0.03262861630178037, 'weapon': 'arrow'},
#  {'dist': 0.06501245006847407, 'weapon': 'arrow'},
#  {'dist': 0.017505514033265564, 'weapon': 'rifle'},
#  {'dist': 0.03268649586061261, 'weapon': 'rifle'},
#  {'dist': 0.030771209190907627, 'weapon': 'rifle'},
#  {'dist': 0.04908349909869938, 'weapon': 'arrow'},
#  {'dist': 0.03518274252200227, 'weapon': 'bomb'},
#  {'dist': 0.017712216829795183, 'weapon': 'arrow'},
#  {'dist': 0.04059350998323279, 'weapon': 'bomb'},
#  {'dist': 0.03611382492266082, 'weapon': 'arrow'},
#  {'dist': 0.064243367511365, 'weapon': 'bomb'},
#  {'dist': 0.006988977149685511, 'weapon': 'bomb'},
#  {'dist': 0.033628468277360574, 'weapon': 'rifle'},
#  {'dist': 0.07824878793234516, 'weapon': 'arrow'},
#  {'dist': 0.03775222534174213, 'weapon': 'rifle'},
#  {'dist': 0.02757720359534583, 'weapon': 'arrow'},
#  {'dist': 0.027064901263484927, 'weapon': 'rifle'},
#  {'dist': 0.03403565647169023, 'weapon': 'bomb'},
#  {'dist': 0.033119350378788076, 'weapon': 'rifle'},
#  {'dist': 0.053508720234701476, 'weapon': 'rifle'},
#  {'dist': 0.00513139222699042, 'weapon': 'arrow'},
#  {'dist': 0.011703540789165152, 'weapon': 'arrow'},
#  {'dist': 0.003809234590621324, 'weapon': 'arrow'},
#  {'dist': 0.005179562012541108, 'weapon': 'rifle'},
#  {'dist': 0.00890276344758964, 'weapon': 'bomb'},
#  {'dist': 0.012868043827077146, 'weapon': 'bomb'},
#  {'dist': 0.046270327214537096, 'weapon': 'rifle'},
#  {'dist': 0.031211460472061355, 'weapon': 'arrow'},
#  {'dist': 0.04047317052252801, 'weapon': 'rifle'},
#  {'dist': 0.014798795991254733, 'weapon': 'bomb'},
#  {'dist': 0.01729457902133668, 'weapon': 'arrow'},
#  {'dist': 0.013251142857064266, 'weapon': 'arrow'},
#  {'dist': 0.0416497924895275, 'weapon': 'rifle'},
#  {'dist': 0.010074416356632128, 'weapon': 'rifle'},
#  {'dist': 0.026274956721218993, 'weapon': 'rifle'},
#  {'dist': 0.02169827211418415, 'weapon': 'arrow'},
#  {'dist': 0.03393540082773056, 'weapon': 'bomb'},
#  {'dist': 0.03757534186628379, 'weapon': 'arrow'},
#  {'dist': 0.02413963438391581, 'weapon': 'arrow'},
#  {'dist': 0.002848382408257713, 'weapon': 'rifle'},
#  {'dist': 0.031472235364345125, 'weapon': 'bomb'},
#  {'dist': 0.03613285027412413, 'weapon': 'rifle'},
#  {'dist': 0.012038499805724016, 'weapon': 'bomb'},
#  {'dist': 0.03759017635264233, 'weapon': 'bomb'},
#  {'dist': 0.04635608193404875, 'weapon': 'arrow'},
#  {'dist': 0.024270673981691214, 'weapon': 'arrow'},
#  {'dist': 0.023711659587125355, 'weapon': 'arrow'},
#  {'dist': 0.0646970579933246, 'weapon': 'rifle'},
#  {'dist': 0.043236715201769825, 'weapon': 'rifle'},
#  {'dist': 0.011601728110256048, 'weapon': 'arrow'},
#  {'dist': 0.015356430579955631, 'weapon': 'arrow'},
#  {'dist': 0.03163469886157952, 'weapon': 'bomb'},
#  {'dist': 0.033200499374384636, 'weapon': 'rifle'},
#  {'dist': 0.021427636211979146, 'weapon': 'arrow'},
#  {'dist': 0.015320998336154785, 'weapon': 'bomb'},
#  {'dist': 0.033186339112506805, 'weapon': 'arrow'},
#  {'dist': 0.01757337810884278, 'weapon': 'bomb'},
#  {'dist': 0.05083877569110449, 'weapon': 'arrow'},
#  {'dist': 0.021086348926581122, 'weapon': 'rifle'},
#  {'dist': 0.026458797860197517, 'weapon': 'rifle'},
#  {'dist': 0.03258991583371983, 'weapon': 'arrow'},
#  {'dist': 0.0405947693609996, 'weapon': 'rifle'},
#  {'dist': 0.053482434407600976, 'weapon': 'rifle'},
#  {'dist': 0.025413876210650138, 'weapon': 'bomb'},
#  {'dist': 0.029117603649359725, 'weapon': 'arrow'},
#  {'dist': 0.06827267452103297, 'weapon': 'bomb'},
#  {'dist': 0.03751493324957979, 'weapon': 'arrow'},
#  {'dist': 0.030943038099200546, 'weapon': 'arrow'},
#  {'dist': 0.025409689919362266, 'weapon': 'bomb'},
#  {'dist': 0.013398914173952604, 'weapon': 'bomb'},
#  {'dist': 0.047525414849967196, 'weapon': 'bomb'},
#  {'dist': 0.019291702083952474, 'weapon': 'bomb'},
#  {'dist': 0.019293751607640696, 'weapon': 'arrow'},
#  {'dist': 0.019950978988981974, 'weapon': 'arrow'},
#  {'dist': 0.040803239135981474, 'weapon': 'bomb'},
#  {'dist': 0.028684247458762867, 'weapon': 'rifle'},
#  {'dist': 0.018077829623204807, 'weapon': 'bomb'},
#  {'dist': 0.062342559325170466, 'weapon': 'bomb'},
#  {'dist': 0.03867733642104347, 'weapon': 'arrow'},
#  {'dist': 0.01291511012562656, 'weapon': 'rifle'},
#  {'dist': 0.07767823638000611, 'weapon': 'bomb'},
#  {'dist': 0.057105346709234686, 'weapon': 'bomb'},
#  {'dist': 0.057008786016656814, 'weapon': 'arrow'},
#  {'dist': 0.02229735793298234, 'weapon': 'arrow'},
#  {'dist': 0.056763923904733136, 'weapon': 'rifle'},
#  {'dist': 0.01115162682293014, 'weapon': 'bomb'},
#  {'dist': 0.03492292456791485, 'weapon': 'bomb'},
#  {'dist': 0.031770171143714866, 'weapon': 'bomb'},
#  {'dist': 0.040693005285650674, 'weapon': 'rifle'},
#  {'dist': 0.05320435688159775, 'weapon': 'rifle'},
#  {'dist': 0.03280872062265279, 'weapon': 'arrow'},
#  {'dist': 0.009152199343635639, 'weapon': 'bomb'},
#  {'dist': 0.031909207212813234, 'weapon': 'bomb'},
#  {'dist': 0.027328015353308786, 'weapon': 'bomb'},
#  {'dist': 0.018701459748006178, 'weapon': 'rifle'},
#  {'dist': 0.05855969347739482, 'weapon': 'arrow'},
#  {'dist': 0.04894662196389835, 'weapon': 'arrow'},
#  {'dist': 0.015953296646627778, 'weapon': 'bomb'},
#  {'dist': 0.01281379819446233, 'weapon': 'rifle'},
#  {'dist': 0.04380933094564712, 'weapon': 'bomb'},
#  {'dist': 0.01818181305150142, 'weapon': 'arrow'},
#  {'dist': 0.02984535665166438, 'weapon': 'arrow'},
#  {'dist': 0.05115990734862633, 'weapon': 'arrow'},
#  {'dist': 0.03449571556091401, 'weapon': 'bomb'},
#  {'dist': 0.03038823140387466, 'weapon': 'rifle'},
#  {'dist': 0.03439236109092178, 'weapon': 'rifle'},
#  {'dist': 0.0356714515385274, 'weapon': 'arrow'},
#  {'dist': 0.02723262081701601, 'weapon': 'bomb'},
#  {'dist': 0.0297090907295738, 'weapon': 'arrow'},
#  {'dist': 0.025874802449375726, 'weapon': 'arrow'},
#  {'dist': 0.056216518719651, 'weapon': 'arrow'},
#  {'dist': 0.028617612086040762, 'weapon': 'arrow'},
#  {'dist': 0.0395951847969273, 'weapon': 'rifle'},
#  {'dist': 0.022203133595455005, 'weapon': 'rifle'},
#  {'dist': 0.032030534960207184, 'weapon': 'bomb'},
#  {'dist': 0.04080559404433207, 'weapon': 'arrow'},
#  {'dist': 0.061865661277085975, 'weapon': 'arrow'},
#  {'dist': 0.01821084484581358, 'weapon': 'rifle'}]
